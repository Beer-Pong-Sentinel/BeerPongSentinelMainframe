# %% [markdown]
# # Aiming Simulation
# This simulation shows how we can determine the azimuth and altitude motor angles to aim the gun at a target point. It uses `scipy.optimize` to iteratively optimize the angles in the rotation matrices of the motors to minimize the normal distnace between the expected trajectory and the target point.

# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
from scipy.optimize import minimize
import time

# %% [markdown]
# # Helper Functions

# %%
def rotate_vector(azimuth_angle, altitude_angle, axis_params, azimuth_params, altitude_params):
    """
    Rotate the given vector and its origin using azimuth and altitude angles,
    explicitly considering the origins of the azimuth and altitude axes.

    :param azimuth_angle: Rotation angle around the azimuth axis (in radians).
    :param altitude_angle: Rotation angle around the altitude axis (in radians).
    :param axis_params: Dictionary containing 'origin' and 'direction' for the vector.
    :param azimuth_params: Dictionary containing 'origin' and 'axis' for the azimuth motor.
    :param altitude_params: Dictionary containing 'origin' and 'axis' for the altitude motor.
    :return: Rotated origin and direction as (rotated_origin, rotated_direction).
    """
    def rodrigues_rotation_matrix(axis, angle):
        """
        Compute the rotation matrix for a given axis and angle using Rodrigues' rotation formula.

        :param axis: Axis of rotation (3D vector).
        :param angle: Angle of rotation (in radians).
        :return: 3x3 rotation matrix.
        """
        axis = axis / np.linalg.norm(axis)  # Normalize the axis
        cos_angle = np.cos(angle)
        sin_angle = np.sin(angle)
        one_minus_cos = 1 - cos_angle

        # Rodrigues' rotation formula components
        skew_symmetric = np.array([
            [0, -axis[2], axis[1]],
            [axis[2], 0, -axis[0]],
            [-axis[1], axis[0], 0]
        ])
        return cos_angle * np.eye(3) + one_minus_cos * np.outer(axis, axis) + sin_angle * skew_symmetric

    # Extract vector origin and direction
    axis_origin = axis_params['origin']
    axis_direction = axis_params['direction']

    # Step 1: Rotate around the azimuth axis
    azimuth_origin = azimuth_params['origin']
    azimuth_axis = azimuth_params['axis']

    # Translate the vector origin relative to the azimuth axis origin
    origin_relative_to_azimuth = axis_origin - azimuth_origin
    R_azimuth = rodrigues_rotation_matrix(azimuth_axis, azimuth_angle)

    # Apply azimuth rotation
    rotated_origin_azimuth = R_azimuth @ origin_relative_to_azimuth + azimuth_origin
    rotated_direction_azimuth = R_azimuth @ axis_direction

    # Step 2: Rotate around the altitude axis
    altitude_origin_relative_to_azimuth = altitude_params['origin'] - azimuth_origin
    altitude_origin = R_azimuth @ altitude_origin_relative_to_azimuth + azimuth_origin
    altitude_axis = R_azimuth @ altitude_params['axis']

    # Translate the origin relative to the altitude axis origin
    origin_relative_to_altitude = rotated_origin_azimuth - altitude_origin
    R_altitude = rodrigues_rotation_matrix(altitude_axis, altitude_angle)

    # Apply altitude rotation
    rotated_origin = R_altitude @ origin_relative_to_altitude + altitude_origin
    rotated_direction = R_altitude @ rotated_direction_azimuth

    return rotated_origin, rotated_direction


# Function to minimize (error between rotated axis and target direction)
def objective(angles, target, axis_params, azimuth_params, altitude_params):
    azimuth_angle, altitude_angle = angles
    # Rotate the axis and calculate the direction
    rotated_origin, rotated_direction = rotate_vector(azimuth_angle, altitude_angle, axis_params, azimuth_params, altitude_params)

    # Calculate the direction to the target point
    direction_to_target = target - rotated_origin
    direction_to_target = direction_to_target / np.linalg.norm(direction_to_target)  # Normalize

    # Minimize the difference between the rotated direction and target direction
    error = np.linalg.norm(rotated_direction - direction_to_target)
    return error

# Function to calculate the shortest normal distance from the vector to the target point
def calculate_shortest_distance(rotated_direction, target, rotated_origin):
    direction_to_target = target - rotated_origin
    cross_product = np.cross(direction_to_target, rotated_direction)
    distance = np.linalg.norm(cross_product) / np.linalg.norm(rotated_direction)
    return distance

# Main function to optimize the azimuth and altitude angles
def optimize_rotation(azimuth_params, altitude_params, axis_params, target):
    # Extract parameters
    axis_origin = axis_params['origin']
    axis_direction = axis_params['direction']

    azimuth_axis = azimuth_params['axis']
    altitude_axis = altitude_params['axis']

    # Initial guess for azimuth and altitude angles (in radians)
    initial_guess = [0, 0]

    # Start timing the optimization process
    start_time = time.time()

    # Minimize the objective function to find the optimal angles
    result = minimize(objective, initial_guess, args=(target, axis_params, azimuth_params, altitude_params), bounds=[(-np.pi, np.pi), (-np.pi/2, np.pi/2)])

    # End timing the optimization process
    end_time = time.time()

    # Extract the optimal angles in radians
    optimal_azimuth, optimal_altitude = result.x

    # Convert the angles to degrees for readability
    optimal_azimuth_deg = np.degrees(optimal_azimuth)
    optimal_altitude_deg = np.degrees(optimal_altitude)

    # Calculate the final vector after the optimal rotation
    final_origin, final_vector = rotate_vector(optimal_azimuth, optimal_altitude, axis_params, azimuth_params, altitude_params)

    # Calculate the error: shortest normal distance between the vector and the target
    distance = calculate_shortest_distance(final_vector, target, final_origin)

    # Print the results
    print(f"Optimal Azimuth Angle: {optimal_azimuth_deg:.2f} degrees")
    print(f"Optimal Altitude Angle: {optimal_altitude_deg:.2f} degrees")
    print(f"Final Vector: {final_vector}")
    print(f"Final Origin: {final_origin}")
    print(f"Shortest Normal Distance to Target: {distance:.3f} units")

    # Print the time taken for the optimization
    print(f"Optimization took {1000 * (end_time - start_time):.3f} ms")

    return [(optimal_azimuth, optimal_altitude),final_vector, final_origin]



def create_cylinder(origin, axis, radius, height, azimuth_angle=0, resolution=50):
    """
    Create the vertices of a rotated cylinder for plotting.
    :param origin: The base center of the cylinder (numpy array).
    :param axis: The direction of the cylinder's axis (numpy array).
    :param radius: Radius of the cylinder.
    :param height: Height of the cylinder.
    :param azimuth_angle: Rotation angle around the azimuth axis (in radians).
    :param resolution: Number of points for circle discretization.
    :return: (x, y, z) coordinates of the cylinder.
    """
    # Normalize the axis
    axis = axis / np.linalg.norm(axis)

    # Apply azimuth rotation to the cylinder's axis
    azimuth_rotation_matrix = np.array([
        [np.cos(azimuth_angle), -np.sin(azimuth_angle), 0],
        [np.sin(azimuth_angle), np.cos(azimuth_angle), 0],
        [0, 0, 1]
    ])
    rotated_axis = azimuth_rotation_matrix @ axis

    # Generate orthogonal vectors for the circular base
    if np.allclose(rotated_axis, [0, 0, 1]):
        # If axis is along z, choose x and y for base
        u = np.array([1, 0, 0])
        v = np.array([0, 1, 0])
    else:
        # Generate orthogonal vectors using cross products
        u = np.cross(rotated_axis, [0, 0, 1])
        u = u / np.linalg.norm(u)
        v = np.cross(rotated_axis, u)

    # Create a circle in the plane orthogonal to the rotated axis
    theta = np.linspace(0, 2 * np.pi, resolution)
    circle = radius * (np.outer(np.cos(theta), u) + np.outer(np.sin(theta), v))

    # Create the bottom and top circles of the cylinder
    bottom_circle = circle + origin
    top_circle = circle + origin + rotated_axis * height

    # Stack the coordinates for plotting
    x = np.vstack((bottom_circle[:, 0], top_circle[:, 0]))
    y = np.vstack((bottom_circle[:, 1], top_circle[:, 1]))
    z = np.vstack((bottom_circle[:, 2], top_circle[:, 2]))

    return x, y, z

# %%
def plot_components(fig, az_params, al_params, ax_params, result, color='green', plot_assembly=True, prefix=""):

  normalized_trajectory = result[1] / np.linalg.norm(result[1])
  rotated_origin = result[2]

  if plot_assembly:
    # Add the azimuth motor as a cylinder
    azimuth_cylinder = create_cylinder(
        az_params['origin'],
        az_params['axis'],
        az_params['radius'],
        az_params['length']
    )
    fig.add_trace(go.Surface(
        x=azimuth_cylinder[0],
        y=azimuth_cylinder[1],
        z=azimuth_cylinder[2],
        showscale=False,
        opacity=0.5,
        colorscale=[[0, color], [1, color]]
    ))

    # Add the altitude motor as a cylinder
    altitude_cylinder = create_cylinder(
        al_params['origin'],
        al_params['axis'],
        al_params['radius'],
        al_params['length'],
        azimuth_angle = result[0][0]
    )
    fig.add_trace(go.Surface(
        x=altitude_cylinder[0],
        y=altitude_cylinder[1],
        z=altitude_cylinder[2],
        showscale=False,
        opacity=0.5,
        colorscale=[[0, color], [1, color]]
    ))

    # Add the laser pointer as a thick line

    start = rotated_origin
    end = rotated_origin + normalized_trajectory * ax_params['length']
    fig.add_trace(go.Scatter3d(
        x=[start[0], end[0]],
        y=[start[1], end[1]],
        z=[start[2], end[2]],
        mode='lines',
        line=dict(color=color, width=10),
    ))

  # Add the trajectory as dashed blue line
  start = rotated_origin + normalized_trajectory * ax_params['length']
  end = rotated_origin + normalized_trajectory * 5000
  fig.add_trace(go.Scatter3d(
      x=[start[0], end[0]],
      y=[start[1], end[1]],
      z=[start[2], end[2]],
      mode='lines',
      line=dict(color=color, width=5, dash='dash'),
      name=prefix+"Trajectory"
  ))

# %% [markdown]
# # Setting Simulation Parameters
# These are the parameters that the algorithm will determine from the assembly's geometry relative to the fiducials.

# %%
noise_magnitude_position = 1
noise_magnitude_direction = 0.01

# Uncomment to generate new noise vectors, want to use the same noise vectors to compare between this notebook and the Intersecting Axes notebook
# position_noise_vectors = np.random.normal(0, noise_magnitude_position, size=(3,3))
# direction_noise_vectors = np.random.normal(0, noise_magnitude_direction, size=(3,3))

position_noise_vectors = np.array([[-0.98465473,  0.2169746,  -0.47258125],
 [ 0.60901181,  0.3661066,  -0.56896886],
 [-0.38222116, -0.01193916,  0.09955876]])
direction_noise_vectors = np.array([[-0.02070715, -0.00824072, -0.00234403],
 [-0.0232364,  -0.00349474,  0.00894407],
 [ 0.00148924, -0.00256017,  0.00455199]])
print(position_noise_vectors)
print(direction_noise_vectors)
# Out:
# [[-0.98465473  0.2169746  -0.47258125]
#  [ 0.60901181  0.3661066  -0.56896886]
#  [-0.38222116 -0.01193916  0.09955876]]
# [[-0.02070715 -0.00824072 -0.00234403]
#  [-0.0232364  -0.00349474  0.00894407]
#  [ 0.00148924 -0.00256017  0.00455199]]

# %%
# Original parameters
azimuth_params = {
    'origin': np.array([0, 0, 0], dtype=float),
    'axis': np.array([0, 0, 1], dtype=float),
    'radius': 50.0,
    'length': 100.0
}

altitude_params = {
    'origin': np.array([50, 0, 300], dtype=float),
    'axis': np.array([1, 0, 0], dtype=float),
    'radius': 50.0,
    'length': 100.0
}

axis_params = {
    'origin': np.array([0, 0, 150], dtype=float),
    'direction': np.array([0, 1, 0], dtype=float),
    'length': 150.0
}



# Adding noise to create the "actual" parameters
azimuth_params_actual = {
    'origin': azimuth_params['origin'] + position_noise_vectors[0],
    'axis': azimuth_params['axis'] + direction_noise_vectors[0],
    'radius': azimuth_params['radius'],
    'length': azimuth_params['length']
}

altitude_params_actual = {
    'origin': altitude_params['origin'] + position_noise_vectors[1],
    'axis': altitude_params['axis'] + direction_noise_vectors[1],
    'radius': altitude_params['radius'],
    'length': altitude_params['length']
}

axis_params_actual = {
    'origin': axis_params['origin'] + position_noise_vectors[2],
    'direction': axis_params['direction'] + direction_noise_vectors[2],
    'length': axis_params['length']
}

# %% [markdown]
# # Simulate Aiming For a Single Point
# This first simple example demonstrates aiming at a single point. Note that the optimization is very quick: 5-10ms.

# %%
# Define the target point
target = np.array([1000, 1860, 846])

# aim straight on
# target = np.array([100, 1860, 350])

# No altitude rotation
# target = np.array([1000, 1860, 350])

# No azimuth rotation
# target = np.array([100, 1860, 1500])

# Run the optimization
result = optimize_rotation(azimuth_params, altitude_params, axis_params, target)
# Out:
# Optimal Azimuth Angle: -28.26 degrees
# Optimal Altitude Angle: 18.44 degrees
# Final Vector: [0.44922241 0.83555368 0.31630567]
# Final Origin: [ 22.46726908  41.78912041 157.70140115]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 30.741 ms

# %% [markdown]
# ## Ideal Scenario: Actual Axes Are the Same as Expected Axes
# i.e. the axes directions and positions used in the optimization are exactly equal to their directions and positions in real-life mechanical assembly. This will likely not be the case.

# %%
# Create a figure
fig = go.Figure()

# %%
# Add a scatter point for the target
fig.add_trace(go.Scatter3d(
    x=[target[0]],
    y=[target[1]],
    z=[target[2]],
    mode='markers',
    marker=dict(color='red', size=5),
    name='Target'
))


plot_components(fig, azimuth_params, altitude_params, axis_params, result)
plot_components(fig, azimuth_params, altitude_params, axis_params, [(0,0),np.array([0,1,0]),axis_params['origin']], color='red')



# Update the layout for the 3D visualization
fig.update_layout(scene=dict(
    aspectmode='manual',
    aspectratio=dict(
        x=1,  # Adjust this value if your data's X dimension is significantly different
        y=1,  # Adjust this value if your data's Y dimension is significantly different
        z=1   # Increase Z ratio to avoid squishing
    ),
    xaxis=dict(range=[-3000, 3000], title='X'),
    yaxis=dict(range=[-3000, 3000], title='Y'),
    zaxis=dict(range=[0, 6000], title='Z')
), width=1000, height=800,showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
# %% [markdown]
# ## Realistic Scenario:  Actual Axes Are Not the Same as Expected Axes
# As a result of small deviations in mechanical assembly and camera noise, the directions and origins of the real-life components are not exactly the same as the parameters used in the optimization. We simulate this discrepancy by adding random noise to azimuth_params_actual, altitude_params_actual and axis_params_actual.

# %%
# First calculate the actual trajectory

az = result[0][0]
al = result[0][1]

origin, trajectory = rotate_vector(az, al, axis_params_actual, azimuth_params_actual, altitude_params_actual)

actual_result = [(az, al),trajectory, origin]

print(result)
print(actual_result)
# Out:
# [(-0.4932999329145247, 0.3218326760974571), array([0.44922241, 0.83555368, 0.31630567]), array([ 22.46726908,  41.78912041, 157.70140115])]
# [(-0.4932999329145247, 0.3218326760974571), array([0.46578171, 0.8601991 , 0.30165211]), array([ 22.3942395 ,  42.45361052, 157.97011454])]

# %%
# Create a figure
fig = go.Figure()

# %%
# Add a scatter point for the target
fig.add_trace(go.Scatter3d(
    x=[target[0]],
    y=[target[1]],
    z=[target[2]],
    mode='markers',
    marker=dict(color='red', size=5),
    name='Target'
))


plot_components(fig, azimuth_params_actual, altitude_params_actual, axis_params_actual, actual_result, color='blue')


# Update the layout for the 3D visualization
fig.update_layout(scene=dict(
    aspectmode='manual',
    aspectratio=dict(
        x=1,
        y=1,
        z=1
    ),
    xaxis=dict(range=[-3000, 3000], title='X'),
    yaxis=dict(range=[-3000, 3000], title='Y'),
    zaxis=dict(range=[0, 6000], title='Z')
), width=1000, height=800,showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cb8efee4-e1d0-45f3-ae87-2fec07fc9933" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb8efee4-e1d0-45f3-ae87-2fec07fc9933")) {                    Plotly.newPlot(                        "cb8efee4-e1d0-45f3-ae87-2fec07fc9933",                        [{"marker":{"color":"red","size":5},"mode":"markers","name":"Target","x":[1000],"y":[1860],"z":[846],"type":"scatter3d"},{"colorscale":[[0,"blue"],[1,"blue"]],"opacity":0.5,"showscale":false,"x":[[47.45758576918227,48.956812399140745,49.64717063114073,49.51732480209879,48.56940697693802,46.81898194014093,44.294791622418636,41.03828315900313,37.102928328832654,32.553345549419845,27.464238844222667,21.919171204644496,16.009192488025555,9.831344381502532,3.487066980188698,-2.919466856383367,-9.283062019735352,-15.499228453216096,-21.46589687584304,-27.085094757074117,-32.26455502305061,-36.919231079399104,-40.97269327395981,-44.35838386956206,-47.02070992022852,-48.91595610581123,-50.01300253633985,-50.293835739754556,-49.75384444261935,-48.40189528710432,-46.26018724096638,-43.36388709111239,-39.760552005930414,-35.50934864789955,-30.68008165862786,-25.352047468566816,-19.61273225181584,-13.556375405561976,-7.282422141783766,-0.8938905996195664,5.504319709628693,11.807150349571303,17.91110901535154,23.71596887443027,29.126414288405535,34.05360589315961,38.41663933876209,42.14387373665866,45.17410800108089,47.457585769182266],[47.82
# %% [markdown]
# As you can see, the difference between the expected trajectory (green) and actual trajectory (blue) can be quite significant depending on the magnitude of the noise.

# %% [markdown]
# # Simulating Several Target Points

# %%
# Generate random target points within specified ranges
num_points = 100  # Number of target points to generate

target_points = [
    np.array([
        np.random.uniform(-500, 500),  # x-coordinate
        np.random.uniform(500, 1500),  # y-coordinate
        np.random.uniform(300, 1500)      # z-coordinate
    ]) for _ in range(num_points)
]

target_points
# Out:
# [array([-266.96871544,  811.84431271, 1100.14812945]),
#  array([-419.44081699,  833.36196522, 1164.16654311]),
#  array([-484.61687438, 1067.86356438,  893.7809356 ]),
#  array([-389.72040879,  910.99779415, 1265.50372696]),
#  array([-193.27513593,  818.90566686,  845.747978  ]),
#  array([ 416.85594267, 1250.57343413,  813.56388854]),
#  array([ 433.95710148, 1076.52759217, 1406.53554646]),
#  array([-272.92191636, 1301.86529517,  577.23594792]),
#  array([-215.64590331, 1245.60462102, 1079.0177273 ]),
#  array([ 464.44470172, 1449.32148105,  460.91383855]),
#  array([  5.6382314 , 739.00042402, 447.11089577]),
#  array([-479.63886258,  902.4527757 ,  420.47074599]),
#  array([ 112.24618345, 1416.58622011,  400.87484487]),
#  array([-315.81774826,  692.09138055, 1342.84634605]),
#  array([-140.71049102,  922.66233397,  392.08475864]),
#  array([-213.22750439, 1285.95353663,  386.92917742]),
#  array([  56.3089217 , 1014.47058622,  885.14617981]),
#  array([-445.57128598, 1415.77435228, 1417.96204059]),
#  array([-476.70514521,  701.68486477, 1275.42465788]),
#  array([ 28.21332029, 567.5129527 , 352.75250813]),
#  array([-155.41705701,  732.42211755, 1474.48007535]),
#  array([-287.69912789,  868.81926171, 1121.61177209]),
#  array([-175.52633532, 1287.83358648, 1375.01907534]),
#  array([-472.00534211,  815.81707697,  854.47513813]),
#  array([ 98.68530777, 956.54684168, 509.19447192]),
#  array([-237.14221393, 1290.14155104, 1438.63229168]),
#  array([-166.31957808, 1432.06221853,  696.67282952]),
#  array([  64.7603173 , 1269.50810982,  855.8375388 ]),
#  array([-343.17707752, 1076.74507466,  902.44302164]),
#  array([-147.53651448,  757.37452407,  895.78256337]),
#  array([-342.04817559,  518.53254745, 1205.00217422]),
#  array([345.89528025, 905.35598121, 394.78680015]),
#  array([-92.2110429 , 865.75802475, 867.60290679]),
#  array([ 156.40479644, 1275.30501054, 1257.59431347]),
#  array([-157.80841388,  559.76188948, 1209.9579095 ]),
#  array([236.14562844, 583.8584165 , 563.13634966]),
#  array([-250.40323733, 1209.13218486, 1459.49327918]),
#  array([-456.70132967,  607.50674376,  656.95346919]),
#  array([363.93789006, 822.25860291, 558.13208335]),
#  array([ -99.25598971, 1318.2484662 ,  501.46432416]),
#  array([ 494.86854852, 1089.4818974 ,  639.94057267]),
#  array([-255.55647647,  705.40316295, 1020.92455254]),
#  array([-348.45288182, 1468.7606581 ,  755.85958996]),
#  array([-376.74070781, 1215.95741074,  914.11465365]),
#  array([-499.19842025, 1179.79863528, 1234.44862582]),
#  array([-322.76098037, 1453.98449452,  671.1534175 ])]

# %%
predicted_results = []
actual_results = []
for target in target_points:
  # Run the optimization
  result = optimize_rotation(azimuth_params, altitude_params, axis_params, target)
  predicted_results.append(result)

    # First calculate the actual trajectory

  az = result[0][0]
  al = result[0][1]

  origin, trajectory = rotate_vector(az, al, axis_params_actual, azimuth_params_actual, altitude_params_actual)

  actual_result = [(az, al),trajectory, origin]
  actual_results.append(actual_result)

print(predicted_results)
print('------------------------------------------------------------------')
print(actual_results)
# Out:
# Optimal Azimuth Angle: 18.20 degrees
# Optimal Altitude Angle: 50.48 degrees
# Final Vector: [-0.198802    0.60455125  0.77135955]
# Final Origin: [-36.14422931 109.91357822 204.5400607 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 39.201 ms
# Optimal Azimuth Angle: 26.72 degrees
# Optimal Altitude Angle: 49.58 degrees
# Final Vector: [-0.2914905   0.5791451   0.76133057]
# Final Origin: [-51.34168259 102.00772997 202.74541319]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 36.519 ms
# Optimal Azimuth Angle: 24.41 degrees
# Optimal Altitude Angle: 33.41 degrees
# Final Vector: [-0.34497393  0.76015737  0.550594  ]
# Final Origin: [-34.13033349  75.20691295 174.78402426]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 21.687 ms
# Optimal Azimuth Angle: 23.16 degrees
# Optimal Altitude Angle: 50.48 degrees
# Final Vector: [-0.25027571  0.58503637  0.77142369]
# Final Origin: [-45.51201849 106.38741832 204.55172397]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 24.778 ms
# Optimal Azimuth Angle: 13.28 degrees
# Optimal Altitude Angle: 41.57 degrees
# Final Vector: [-0.17185336  0.72814175  0.66353298]
# Final Origin: [-22.86255933  96.86853826 187.77794478]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 39.295 ms
# Optimal Azimuth Angle: -18.43 degrees
# Optimal Altitude Angle: 27.37 degrees
# Final Vector: [0.28082255 0.84247143 0.45976145]
# Final Origin: [ 21.80831271  65.42523033 166.79363104]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.536 ms
# Optimal Azimuth Angle: -21.95 degrees
# Optimal Altitude Angle: 49.00 degrees
# Final Vector: [0.24529095 0.60849902 0.75469285]
# Final Origin: [ 42.32406345 104.99429944 201.58825914]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 53.578 ms
# Optimal Azimuth Angle: 11.84 degrees
# Optimal Altitude Angle: 18.11 degrees
# Final Vector: [-0.19501325  0.93023307  0.31086374]
# Final Origin: [ -9.56740431  45.63749219 157.43182655]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 31.126 ms
# Optimal Azimuth Angle: 9.82 degrees
# Optimal Altitude Angle: 37.44 degrees
# Final Vector: [-0.13544322  0.78234134  0.60794503]
# Final Origin: [-15.55620837  89.85510799 180.90313208]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 23.031 ms
# Optimal Azimuth Angle: -17.77 degrees
# Optimal Altitude Angle: 11.66 degrees
# Final Vector: [0.29887242 0.93264539 0.20210851]
# Final Origin: [  9.25162348  28.87012459 153.09552978]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.490 ms
# Optimal Azimuth Angle: -0.44 degrees
# Optimal Altitude Angle: 22.74 degrees
# Final Vector: [0.00703625 0.92223805 0.3865585 ]
# Final Origin: [  0.44237681  57.98208794 161.6602668 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 20.521 ms
# Optimal Azimuth Angle: 27.99 degrees
# Optimal Altitude Angle: 15.10 degrees
# Final Vector: [-0.45310262  0.85252417  0.26057736]
# Final Origin: [-18.34397225  34.51465251 155.18205414]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 29.037 ms
# Optimal Azimuth Angle: -4.53 degrees
# Optimal Altitude Angle: 10.10 degrees
# Final Vector: [0.07776435 0.98141336 0.17544378]
# Final Origin: [  2.07873295  26.23433937 152.32658226]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 36.020 ms
# Optimal Azimuth Angle: 24.53 degrees
# Optimal Altitude Angle: 60.56 degrees
# Final Vector: [-0.20403048  0.44711781  0.8708945 ]
# Final Origin: [-54.23190199 118.84522868 226.27949792]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 32.322 ms
# Optimal Azimuth Angle: 8.67 degrees
# Optimal Altitude Angle: 14.84 degrees
# Final Vector: [-0.14573439  0.95560491  0.25608737]
# Final Origin: [ -5.79122688  37.97404793 155.00195389]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 28.222 ms
# Optimal Azimuth Angle: 9.41 degrees
# Optimal Altitude Angle: 10.41 degrees
# Final Vector: [-0.16088755  0.97029656  0.18066485]
# Final Origin: [ -4.4329543   26.73469965 152.46829239]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 37.601 ms
# Optimal Azimuth Angle: -3.18 degrees
# Optimal Altitude Angle: 37.29 degrees
# Final Vector: [0.04409227 0.7943734  0.60582735]
# Final Origin: [  5.0362803   90.73443827 180.66057821]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 23.499 ms
# Optimal Azimuth Angle: 17.47 degrees
# Optimal Altitude Angle: 41.62 degrees
# Final Vector: [-0.22442783  0.71310511  0.66416357]
# Final Origin: [-29.90756897  95.02939255 187.86190714]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.047 ms
# Optimal Azimuth Angle: 34.19 degrees
# Optimal Altitude Angle: 55.65 degrees
# Final Vector: [-0.31707392  0.46671611  0.82561505]
# Final Origin: [-69.59375447 102.43834228 215.36492826]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.200 ms
# Optimal Azimuth Angle: -2.85 degrees
# Optimal Altitude Angle: 20.54 degrees
# Final Vector: [0.04649501 0.93525034 0.35092024]
# Final Origin: [  2.61361793  52.57310908 159.53919692]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 40.662 ms
# Optimal Azimuth Angle: 11.98 degrees
# Optimal Altitude Angle: 63.66 degrees
# Final Vector: [-0.09208411  0.43395776  0.89621492]
# Final Origin: [-27.90466945 131.50420497 233.4569801 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 28.927 ms
# Optimal Azimuth Angle: 18.32 degrees
# Optimal Altitude Angle: 48.92 degrees
# Final Vector: [-0.2065625   0.62379571  0.75379762]
# Final Origin: [-35.54361901 107.33776256 201.43400243]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.248 ms
# Optimal Azimuth Angle: 7.76 degrees
# Optimal Altitude Angle: 44.70 degrees
# Final Vector: [-0.09599758  0.70433253  0.70334924]
# Final Origin: [-14.24780508 104.53589569 193.3733309 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 24.484 ms
# Optimal Azimuth Angle: 30.05 degrees
# Optimal Altitude Angle: 38.35 degrees
# Final Vector: [-0.39272611  0.67879034  0.62049165]
# Final Origin: [-46.61040801  80.56172938 182.36804166]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 23.458 ms
# Optimal Azimuth Angle: -5.89 degrees
# Optimal Altitude Angle: 21.04 degrees
# Final Vector: [0.09578147 0.92840022 0.359025  ]
# Final Origin: [  5.52666554  53.56941582 160.00080837]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 33.350 ms
# Optimal Azimuth Angle: 10.42 degrees
# Optimal Altitude Angle: 45.91 degrees
# Final Vector: [-0.12578004  0.68429004  0.71828025]
# Final Origin: [-19.47786132 105.96678587 195.63691644]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.244 ms
# Optimal Azimuth Angle: 6.62 degrees
# Optimal Altitude Angle: 21.14 degrees
# Final Vector: [-0.10759967  0.92646598  0.36067034]
# Final Origin: [ -6.24128118  53.73933336 160.09599556]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 30.811 ms
# Optimal Azimuth Angle: -2.92 degrees
# Optimal Altitude Angle: 29.83 degrees
# Final Vector: [0.044198   0.86642123 0.49735378]
# Final Origin: [  3.80071974  74.50618925 169.8678276 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.938 ms
# Optimal Azimuth Angle: 17.68 degrees
# Optimal Altitude Angle: 34.79 degrees
# Final Vector: [-0.24939304  0.78249027  0.57053667]
# Final Origin: [-25.98795184  81.53924392 176.80918029]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 60.374 ms
# Optimal Azimuth Angle: 11.02 degrees
# Optimal Altitude Angle: 46.52 degrees
# Final Vector: [-0.13155941  0.6753565   0.72566227]
# Final Origin: [-20.81263341 106.84106486 196.79233968]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.913 ms
# Optimal Azimuth Angle: 33.41 degrees
# Optimal Altitude Angle: 63.39 degrees
# Final Vector: [-0.24664936  0.37391143  0.89406618]
# Final Origin: [-73.84583897 111.94759711 232.80976583]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 24.905 ms
# Optimal Azimuth Angle: -20.91 degrees
# Optimal Altitude Angle: 14.45 degrees
# Final Vector: [0.34560934 0.90460755 0.2494782 ]
# Final Origin: [ 13.35559764  34.95731456 154.74293762]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 39.517 ms
# Optimal Azimuth Angle: 6.08 degrees
# Optimal Altitude Angle: 41.40 degrees
# Final Vector: [-0.07944487  0.74589809  0.66130519]
# Final Origin: [-10.50582317  98.63787405 187.482457  ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 24.355 ms
# Optimal Azimuth Angle: -6.99 degrees
# Optimal Altitude Angle: 42.07 degrees
# Final Vector: [0.09036566 0.7368302  0.67001142]
# Final Origin: [ 12.23397843  99.75431835 188.64738107]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 38.878 ms
# Optimal Azimuth Angle: 15.74 degrees
# Optimal Altitude Angle: 65.40 degrees
# Final Vector: [-0.11295441  0.40066035  0.90923737]
# Final Origin: [-37.00736868 131.26876215 237.55829321]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 42.144 ms
# Optimal Azimuth Angle: -22.02 degrees
# Optimal Altitude Angle: 35.37 degrees
# Final Vector: [0.30574454 0.7559383  0.57885884]
# Final Origin: [ 32.55645817  80.49423664 177.68583525]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 39.423 ms
# Optimal Azimuth Angle: 11.70 degrees
# Optimal Altitude Angle: 48.28 degrees
# Final Vector: [-0.13495707  0.65167263  0.7463976 ]
# Final Origin: [-22.70434046 109.63336098 200.17495763]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 29.851 ms
# Optimal Azimuth Angle: 36.93 degrees
# Optimal Altitude Angle: 35.45 degrees
# Final Vector: [-0.48951932  0.65116143  0.57996519]
# Final Origin: [-52.27531119  69.53692124 177.80381174]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.818 ms
# Optimal Azimuth Angle: -23.87 degrees
# Optimal Altitude Angle: 25.24 degrees
# Final Vector: [0.36608396 0.82710731 0.42646925]
# Final Origin: [ 25.89107786  58.49668913 164.32469109]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 28.458 ms
# Optimal Azimuth Angle: 4.31 degrees
# Optimal Altitude Angle: 15.11 degrees
# Final Vector: [-0.07248709  0.96272275  0.26059647]
# Final Origin: [ -2.93488901  38.97913747 155.18282813]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.959 ms
# Optimal Azimuth Angle: -24.43 degrees
# Optimal Altitude Angle: 22.78 degrees
# Final Vector: [0.38128802 0.83942776 0.38727313]
# Final Origin: [ 24.02411195  52.89047977 161.70524524]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 44.605 ms
# Optimal Azimuth Angle: 19.91 degrees
# Optimal Altitude Angle: 52.15 degrees
# Final Vector: [-0.20902155  0.57695454  0.78957802]
# Final Origin: [-40.34191548 111.35431093 207.95247264]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 23.096 ms
# Optimal Azimuth Angle: 13.35 degrees
# Optimal Altitude Angle: 22.26 degrees
# Final Vector: [-0.21362894  0.90046547  0.37884643]
# Final Origin: [-13.11768241  55.29222671 161.18106731]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.463 ms
# Optimal Azimuth Angle: 17.21 degrees
# Optimal Altitude Angle: 31.85 degrees
# Final Vector: [-0.25140165  0.81141671  0.52763637]
# Final Origin: [-23.42318137  75.59998409 172.57944836]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 35.893 ms
# Optimal Azimuth Angle: -10.50 degrees
# Optimal Altitude Angle: 16.53 degrees
# Final Vector: [0.17473523 0.94262898 0.28446127]
# Final Origin: [  7.77710198  41.95445696 156.1968699 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 24.861 ms
# Optimal Azimuth Angle: 15.48 degrees
# Optimal Altitude Angle: 21.56 degrees
# Final Vector: [-0.2482833   0.89626282  0.36751648]
# Final Origin: [-14.71718314  53.12666689 160.49744882]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 32.976 ms
# Optimal Azimuth Angle: 16.61 degrees
# Optimal Altitude Angle: 29.35 degrees
# Final Vector: [-0.24912079  0.83527761  0.49015319]
# Final Origin: [-21.01346918  70.45610338 169.25455416]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.695 ms
# Optimal Azimuth Angle: 25.35 degrees
# Optimal Altitude Angle: 10.95 degrees
# Final Vector: [-0.42034022  0.88725712  0.18997077]
# Final Origin: [-12.20001875  25.75188631 152.73153802]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 37.803 ms
# Optimal Azimuth Angle: 10.53 degrees
# Optimal Altitude Angle: 33.08 degrees
# Final Vector: [-0.15309422  0.82376055  0.5458761 ]
# Final Origin: [-14.96130941  80.50295176 174.32011307]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 22.401 ms
# Optimal Azimuth Angle: 20.36 degrees
# Optimal Altitude Angle: 37.28 degrees
# Final Vector: [-0.27688091  0.74591154  0.6057664 ]
# Final Origin: [-31.62069818  85.18551802 180.65361771]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.292 ms
# Optimal Azimuth Angle: -23.85 degrees
# Optimal Altitude Angle: 39.62 degrees
# Final Vector: [0.31144211 0.70448693 0.6377319 ]
# Final Origin: [ 38.67855849  87.49150637 184.46123843]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 21.878 ms
# Optimal Azimuth Angle: 22.10 degrees
# Optimal Altitude Angle: 28.60 degrees
# Final Vector: [-0.33031259  0.81348812  0.47867595]
# Final Origin: [-27.01267629  66.52635011 168.30125262]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 30.782 ms
# Optimal Azimuth Angle: -19.54 degrees
# Optimal Altitude Angle: 33.35 degrees
# Final Vector: [0.27939614 0.7872157  0.5497538 ]
# Final Origin: [ 27.58185755  77.71356987 174.70098886]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 24.903 ms
# Optimal Azimuth Angle: -19.42 degrees
# Optimal Altitude Angle: 45.09 degrees
# Final Vector: [0.23478414 0.66585682 0.70817448]
# Final Origin: [ 35.32421745 100.18083368 194.09438057]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.740 ms
# Optimal Azimuth Angle: 4.70 degrees
# Optimal Altitude Angle: 37.31 degrees
# Final Vector: [-0.06516047  0.79268501  0.60613908]
# Final Origin: [ -7.44877291  90.6152244  180.69619918]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 20.694 ms
# Optimal Azimuth Angle: -17.16 degrees
# Optimal Altitude Angle: 30.18 degrees
# Final Vector: [0.25506937 0.82594071 0.50275397]
# Final Origin: [ 22.25232935  72.05531803 170.33556778]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 35.356 ms
# Optimal Azimuth Angle: 14.66 degrees
# Optimal Altitude Angle: 31.48 degrees
# Final Vector: [-0.21583969  0.82508898  0.52215074]
# Final Origin: [-19.82184954  75.77285584 172.07201792]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.322 ms
# Optimal Azimuth Angle: -25.05 degrees
# Optimal Altitude Angle: 57.73 degrees
# Final Vector: [0.22603585 0.48370105 0.84554189]
# Final Origin: [ 53.69531603 114.90425408 219.91363767]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.592 ms
# Optimal Azimuth Angle: 3.37 degrees
# Optimal Altitude Angle: 29.74 degrees
# Final Vector: [-0.05101571  0.86675659  0.49611532]
# Final Origin: [ -4.37249903  74.2887305  169.76150426]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 31.735 ms
# Optimal Azimuth Angle: 16.05 degrees
# Optimal Altitude Angle: 56.58 degrees
# Final Vector: [-0.15230937  0.52927673  0.8346664 ]
# Final Origin: [-34.62355903 120.31724345 217.38662282]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 30.359 ms
# Optimal Azimuth Angle: 33.54 degrees
# Optimal Altitude Angle: 22.93 degrees
# Final Vector: [-0.50891439  0.76760352  0.38960361]
# Final Origin: [-32.2929349   48.70793832 161.85260372]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 28.111 ms
# Optimal Azimuth Angle: -3.07 degrees
# Optimal Altitude Angle: 52.03 degrees
# Final Vector: [0.03294311 0.6143014  0.7883835 ]
# Final Origin: [  6.33269123 118.08784476 207.72238657]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.617 ms
# Optimal Azimuth Angle: -16.88 degrees
# Optimal Altitude Angle: 23.15 degrees
# Final Vector: [0.26695342 0.87989024 0.39310183]
# Final Origin: [ 17.1191603   56.42550758 162.07575831]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 32.023 ms
# Optimal Azimuth Angle: -8.69 degrees
# Optimal Altitude Angle: 12.38 degrees
# Final Vector: [0.14756768 0.96552339 0.21444896]
# Final Origin: [  4.85992545  31.79809899 153.48972041]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 22.108 ms
# Optimal Azimuth Angle: 1.84 degrees
# Optimal Altitude Angle: 24.05 degrees
# Final Vector: [-0.02938251  0.91272139  0.40752465]
# Final Origin: [ -1.96684824  61.09704642 163.02086864]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 30.353 ms
# Optimal Azimuth Angle: -25.62 degrees
# Optimal Altitude Angle: 34.91 degrees
# Final Vector: [0.35459701 0.73943068 0.57227899]
# Final Origin: [ 37.11838092  77.40186453 176.99115006]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.448 ms
# Optimal Azimuth Angle: -4.08 degrees
# Optimal Altitude Angle: 44.56 degrees
# Final Vector: [0.05071219 0.71073872 0.70162578]
# Final Origin: [  7.49025355 104.97698676 193.11815705]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 42.533 ms
# Optimal Azimuth Angle: 14.21 degrees
# Optimal Altitude Angle: 30.99 degrees
# Final Vector: [-0.21040669  0.83104041  0.51487946]
# Final Origin: [-18.95581682  74.86952796 171.41061167]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 37.122 ms
# Optimal Azimuth Angle: -11.51 degrees
# Optimal Altitude Angle: 66.55 degrees
# Final Vector: [0.07938926 0.38993291 0.91741467]
# Final Origin: [ 27.45422536 134.84577506 240.31011427]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.764 ms
# Optimal Azimuth Angle: -9.13 degrees
# Optimal Altitude Angle: 42.61 degrees
# Final Vector: [0.11672327 0.72664366 0.67702635]
# Final Origin: [ 16.10648595 100.26857056 189.60618283]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 28.248 ms
# Optimal Azimuth Angle: -18.06 degrees
# Optimal Altitude Angle: 8.60 degrees
# Final Vector: [0.30654834 0.94002298 0.14961591]
# Final Origin: [  6.957994    21.33651829 151.68837097]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.382 ms
# Optimal Azimuth Angle: 6.72 degrees
# Optimal Altitude Angle: 42.25 degrees
# Final Vector: [-0.0866755   0.73515785  0.67233198]
# Final Origin: [-11.80845567 100.15608839 188.96253635]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.640 ms
# Optimal Azimuth Angle: -10.93 degrees
# Optimal Altitude Angle: 11.02 degrees
# Final Vector: [0.1861806  0.96373914 0.19116394]
# Final Origin: [  5.43895695  28.15403863 152.76628152]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 22.120 ms
# Optimal Azimuth Angle: -15.92 degrees
# Optimal Altitude Angle: 46.14 degrees
# Final Vector: [0.19005429 0.66634296 0.72101763]
# Final Origin: [ 29.66427748 104.00492909 196.06249298]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 40.710 ms
# Optimal Azimuth Angle: 32.10 degrees
# Optimal Altitude Angle: 60.61 degrees
# Final Vector: [-0.26076153  0.41573212  0.87130375]
# Final Origin: [-69.44632663 110.71828141 226.38838489]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.692 ms
# Optimal Azimuth Angle: 19.88 degrees
# Optimal Altitude Angle: 51.09 degrees
# Final Vector: [-0.21359296  0.5906632   0.77813562]
# Final Origin: [-39.69238939 109.76407698 205.78555509]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 31.996 ms
# Optimal Azimuth Angle: 25.89 degrees
# Optimal Altitude Angle: 26.21 degrees
# Final Vector: [-0.39169209  0.80713981  0.44170423]
# Final Origin: [-28.9265985   59.6075586  165.42589084]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 42.538 ms
# Optimal Azimuth Angle: -10.11 degrees
# Optimal Altitude Angle: 43.73 degrees
# Final Vector: [0.12683597 0.7114445  0.69120139]
# Final Origin: [ 18.1971323  102.07080822 191.60067119]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.505 ms
# Optimal Azimuth Angle: -12.04 degrees
# Optimal Altitude Angle: 31.22 degrees
# Final Vector: [0.17837181 0.83637354 0.51832692]
# Final Origin: [ 16.21669764  76.03901419 171.72261681]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 42.555 ms
# Optimal Azimuth Angle: 3.28 degrees
# Optimal Altitude Angle: 18.00 degrees
# Final Vector: [-0.05440374  0.94948946  0.30904691]
# Final Origin: [ -2.6518109   46.28112706 157.34298063]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 22.997 ms
# Optimal Azimuth Angle: -18.63 degrees
# Optimal Altitude Angle: 46.25 degrees
# Final Vector: [0.22091654 0.65524613 0.72239074]
# Final Origin: [ 34.61854879 102.67981682 196.27723828]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.281 ms
# Optimal Azimuth Angle: 4.54 degrees
# Optimal Altitude Angle: 27.76 degrees
# Final Vector: [-0.07003324  0.88210182  0.4658237 ]
# Final Origin: [ -5.53011116  69.65437289 167.26836772]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 22.254 ms
# Optimal Azimuth Angle: 11.94 degrees
# Optimal Altitude Angle: 26.07 degrees
# Final Vector: [-0.18584505  0.87883235  0.43944889]
# Final Origin: [-13.63781819  64.49112106 165.2598604 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 26.664 ms
# Optimal Azimuth Angle: -35.99 degrees
# Optimal Altitude Angle: 59.83 degrees
# Final Vector: [0.29525373 0.40660211 0.8645808 ]
# Final Origin: [ 76.20114716 104.93871628 224.62592623]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 32.765 ms
# Optimal Azimuth Angle: -31.24 degrees
# Optimal Altitude Angle: 58.78 degrees
# Final Vector: [0.26881317 0.44309923 0.85522076]
# Final Origin: [ 66.53790175 109.67800649 222.26041855]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.331 ms
# Optimal Azimuth Angle: 14.21 degrees
# Optimal Altitude Angle: 28.41 degrees
# Final Vector: [-0.21593359  0.85264529  0.4757822 ]
# Final Origin: [-17.52074754  69.18322918 168.06553064]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 34.616 ms
# Optimal Azimuth Angle: 32.43 degrees
# Optimal Altitude Angle: 54.60 degrees
# Final Vector: [-0.31067128  0.48891517  0.81513515]
# Final Origin: [-65.57530601 103.19834643 213.10937601]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 34.096 ms
# Optimal Azimuth Angle: -21.54 degrees
# Optimal Altitude Angle: 37.72 degrees
# Final Vector: [0.29040892 0.73580013 0.61176861]
# Final Origin: [ 33.68927962  85.35748998 181.34448457]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 30.037 ms
# Optimal Azimuth Angle: -10.41 degrees
# Optimal Altitude Angle: 34.32 degrees
# Final Vector: [0.14918037 0.81236458 0.56374552]
# Final Origin: [ 15.27330598  83.17108143 176.10771881]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.577 ms
# Optimal Azimuth Angle: 25.41 degrees
# Optimal Altitude Angle: 41.21 degrees
# Final Vector: [-0.32282115  0.67952746  0.65880872]
# Final Origin: [-42.40484332  89.2607426  187.15342675]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 25.537 ms
# Optimal Azimuth Angle: 16.06 degrees
# Optimal Altitude Angle: 54.09 degrees
# Final Vector: [-0.16219431  0.56358504  0.80997834]
# Final Origin: [-33.6017605  116.75779315 212.03103144]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 46.042 ms
# Optimal Azimuth Angle: -12.39 degrees
# Optimal Altitude Angle: 23.82 degrees
# Final Vector: [0.19628258 0.89352024 0.40384988]
# Final Origin: [ 12.9973505   59.16671601 162.7762098 ]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 35.460 ms
# Optimal Azimuth Angle: -8.11 degrees
# Optimal Altitude Angle: 13.67 degrees
# Final Vector: [0.13701302 0.96198384 0.236251  ]
# Final Origin: [  4.99687041  35.08358988 154.24619042]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 27.577 ms
# Optimal Azimuth Angle: 9.80 degrees
# Optimal Altitude Angle: 29.00 degrees
# Final Vector: [-0.1488395   0.86186755  0.48480009]
# Final Origin: [-12.3751444   71.6593068  168.80625186]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 37.601 ms
# Optimal Azimuth Angle: 14.64 degrees
# Optimal Altitude Angle: 39.87 degrees
# Final Vector: [-0.19401134  0.74252917  0.64110064]
# Final Origin: [-24.31031732  93.04157221 184.88147711]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took 55.425 ms
# Optimal Azimuth Angle: -5.03 degrees
# Optimal Altitude Angle: 56.24 degrees
# Final Vector: [0.04869223 0.55351694 0.83141329]
# Final Origin: [ 10.92856191 124.2322339  216.65182309]
# Shortest Normal Distance to Target: 0.000 units
# Optimization took
  plot_components(fig, azimuth_params, altitude_params, axis_params, predicted_result, color='green', plot_assembly=False)
  plot_components(fig, azimuth_params_actual, altitude_params_actual, axis_params_actual, actual_result, color='blue', plot_assembly=False)


# Update the layout for the 3D visualization
fig.update_layout(scene=dict(
    aspectmode='manual',
    aspectratio=dict(
        x=1,
        y=1,
        z=1
    ),
    xaxis=dict(range=[-3000, 3000], title='X'),
    yaxis=dict(range=[-3000, 3000], title='Y'),
    zaxis=dict(range=[0, 6000], title='Z')
), width=1000, height=800,showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d3ec6ae9-dfcd-4392-87fa-c30515535952" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3ec6ae9-dfcd-4392-87fa-c30515535952")) {                    Plotly.newPlot(                        "d3ec6ae9-dfcd-4392-87fa-c30515535952",                        [{"marker":{"color":"red","size":5},"mode":"markers","name":"Target","x":[421.8890104495557],"y":[1193.309164709822],"z":[596.7865458471927],"type":"scatter3d"},{"line":{"color":"green","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[63.991372224451254,1584.8382412193635],"y":[180.9990017563926,4482.700239649715],"z":[209.75330674190258,1854.4086691128286],"type":"scatter3d"},{"line":{"color":"blue","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[63.45627135960964,1575.7122779081583],"y":[178.74728112243048,4464.011204657676],"z":[211.46009759156541,1906.1857026100154],"type":"scatter3d"},{"marker":{"color":"red","size":5},"mode":"markers","name":"Target","x":[63.46069797244479],"y":[996.8312124250392],"z":[453.6553195702906],"type":"scatter3d"},{"line":{"color":"green","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[11.930882674160486,306.1600265429244],"y":[187.40852998822533,4809.116146941141],"z":[201.33036472010312,1642.0759752626634],"type":"scatter3d"},{"line":{"color":"blue","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[11.484566972389144,299.1933170980373],"y":[186.5785006721513,4800.170380071757],"z":[202.1056869502741,1669.9250373606533],"type":"scatter3d"},{"marker":{"color":"red","size":5},"mode":"markers","name":"Target","x":[77.03775954227308],"y":[630.0674393353074],"z":[1204.4912561471301],"type":"scatter3d"},{"line":{"color":"green","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[24.521078852154794,294.1163928938795],"y":[200.55013067630392,2405.4847417012143],"z":[364.64024889837475,4676.030016450269],"type":"scatter3d"},{"line":{"color":"blue","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[22.71559368519369,252.24125731608788],"y":[198.40809471705887,2377.767929441848],"z":[364.41662336993306,4691.102269511],"type":"scatter3d"},{"marker":{"color":"red","size":5},"mode":"markers","name":"Target","x":[-82.51617825996362],"y":[869.6802064774125],"z":[453.5956927665132],"type":"scatter3d"},{"line":{"color":"green","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[-18.11660878895794,-449.39710846980654],"y":[190.94020199738816,4736.425876821213],"z":[209.37093321023076,1844.931115706257],"type":"scatter3d"},{"line":{"color":"blue","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[-18.772400454582353,-459.40640377058577],"y":[190.79340506825355,4731.1795542281525],"z":[209.474211453297,1856.6643315179674],"type":"scatter3d"},{"marker":{"color":"red","size":5},"mode":"markers","name":"Target","x":[-143.84664600202666],"y":[1283.8684793165773],"z":[306.5922351062397],"type":"scatter3d"},{"line":{"color":"green","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[-18.602462900146783,-554.6459131620848],"y":[166.0317904380763,4950.35816040983],"z":[169.28124488821288,756.9704527389194],"type":"scatter3d"},{"line":{"color":"blue","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[-19.004722341172897,-553.5312000116081],"y":[166.2682276148813,4949.453716132129],"z":[169.58942111571452,767.8519279697385],"type":"scatter3d"},{"marker":{"color":"red","size":5},"mode":"markers","name":"Target","x":[240.01304710598083],"y":[1086.6771834241315],"z":[815.1999575729382],"type":"scatter3d"},{"line":{"color":"green","dash":"dash","width":5},"mode":"lines","name":"Trajectory","x":[44.55418239384705,932.8956324390288] ...

# %% [markdown]
# The motors and the gun were not plotted becuase they made the plot laggy. Next, we must calculate the errors between the predicted, actual and target. Again, green is the expected trajectory and blue is the actual trajectory.

# %%
# Calculate the error: shortest normal distance between the vector and the target

max_error = 0
for target, predicted_result, actual_result in zip(target_points, predicted_results, actual_results):

  predicted_vector = predicted_result[1]
  actual_vector = actual_result[1]

  predicated_rotated_origin = predicted_result[2]
  actual_rotated_origin = actual_result[2]

  print(f"Target: {target}")

  print(f"Predicted vector: {predicted_vector}, \nActual vector: {actual_vector}")

  predicted_distance = calculate_shortest_distance(predicted_vector, target, predicated_rotated_origin)
  actual_distance = calculate_shortest_distance(actual_vector, target, actual_rotated_origin)
  max_error = max(max_error, actual_distance)

  print(f"Predicted shortest dist: {predicted_distance:.5f} mm, \nActual shortest dist: {actual_distance:.5f} mm\n")

print(max_error)
# Out:
# Target: [-266.96871544  811.84431271 1100.14812945]
# Predicted vector: [-0.198802    0.60455125  0.77135955],
# Actual vector: [-0.20644742  0.60223006  0.76785908]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 10.93364 mm
#
# Target: [-419.44081699  833.36196522 1164.16654311]
# Predicted vector: [-0.2914905   0.5791451   0.76133057],
# Actual vector: [-0.29962638  0.57800381  0.75567505]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 14.27352 mm
#
# Target: [-484.61687438 1067.86356438  893.7809356 ]
# Predicted vector: [-0.34497393  0.76015737  0.550594  ],
# Actual vector: [-0.34963471  0.75856899  0.5451952 ]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 10.52425 mm
#
# Target: [-389.72040879  910.99779415 1265.50372696]
# Predicted vector: [-0.25027571  0.58503637  0.77142369],
# Actual vector: [-0.25828757  0.58342097  0.76669202]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 14.23795 mm
#
# Target: [-193.27513593  818.90566686  845.747978  ]
# Predicted vector: [-0.17185336  0.72814175  0.66353298],
# Actual vector: [-0.17763061  0.72511776  0.66148376]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 7.00490 mm
#
# Target: [ 416.85594267 1250.57343413  813.56388854]
# Predicted vector: [0.28082255 0.84247143 0.45976145],
# Actual vector: [0.27714525 0.83609133 0.4680288 ]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 16.09724 mm
#
# Target: [ 433.95710148 1076.52759217 1406.53554646]
# Predicted vector: [0.24529095 0.60849902 0.75469285],
# Actual vector: [0.23837899 0.59993239 0.7603721 ]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 21.16865 mm
#
# Target: [-272.92191636 1301.86529517  577.23594792]
# Predicted vector: [-0.19501325  0.93023307  0.31086374],
# Actual vector: [-0.19634128  0.92744202  0.31017827]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 2.96606 mm
#
# Target: [-215.64590331 1245.60462102 1079.0177273 ]
# Predicted vector: [-0.13544322  0.78234134  0.60794503],
# Actual vector: [-0.14036455  0.778889    0.60707403]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 8.55038 mm
#
# Target: [ 464.44470172 1449.32148105  460.91383855]
# Predicted vector: [0.29887242 0.93264539 0.20210851],
# Actual vector: [0.29766439 0.92813365 0.21183245]
# Predicted shortest dist: 0.00002 mm,
# Actual shortest dist: 16.43033 mm
#
# Target: [  5.6382314  739.00042402 447.11089577]
# Predicted vector: [0.00703625 0.92223805 0.3865585 ],
# Actual vector: [0.00470587 0.91807924 0.38989424]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 3.98741 mm
#
# Target: [-479.63886258  902.4527757   420.47074599]
# Predicted vector: [-0.45310262  0.85252417  0.26057736],
# Actual vector: [-0.45381932  0.85114681  0.25398087]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 7.39191 mm
#
# Target: [ 112.24618345 1416.58622011  400.87484487]
# Predicted vector: [0.07776435 0.98141336 0.17544378],
# Actual vector: [0.0774189  0.97782208 0.18105094]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 8.86435 mm
#
# Target: [-315.81774826  692.09138055 1342.84634605]
# Predicted vector: [-0.20403048  0.44711781  0.8708945 ],
# Actual vector: [-0.21395303  0.44580359  0.86625193]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 15.78411 mm
#
# Target: [-140.71049102  922.66233397  392.08475864]
# Predicted vector: [-0.14573439  0.95560491  0.25608737],
# Actual vector: [-0.14649338  0.95265241  0.2567143 ]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 1.77806 mm
#
# Target: [-213.22750439 1285.95353663  386.92917742]
# Predicted vector: [-0.16088755  0.97029656  0.18066485],
# Actual vector: [-0.16081912  0.96757466  0.18123368]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 1.47690 mm
#
# Target: [  56.3089217  1014.47058622  885.14617981]
# Predicted vector: [0.04409227 0.7943734  0.60582735],
# Actual vector: [0.03930801 0.78915391 0.60876936]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 8.75738 mm
#
# Target: [-445.57128598 1415.77435228 1417.96204059]
# Predicted vector: [-0.22442783  0.71310511  0.66416357],
# Actual vector: [-0.2304003   0.71065866  0.66090023]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 13.58530 mm
#
# Target: [-476.70514521  701.68486477 1275.42465788]
# Predicted vector: [-0.31707392  0.46671611  0.82561505],
# Actual vector: [-0.32714669  0.46661403  0.81863028]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 18.40366 mm
#
# Target: [ 28.21332029 567.5129527  352.75250813]
# Predicted vector: [0.04649501 0.93525034 0.35092024],
# Actual vector: [0.04447846 0.93099389 0.35521992]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 3.39127 mm
#
# Target: [-155.41705701  732.42211755 1474.48007535]
# Predicted vector: [-0.09208411  0.43395776  0.89621492],
# Actual vector: [-0.10140503  0.43077077  0.89390308]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 14.51189 mm
#
# Target: [-287.69912789  868.81926171 1121.61177209]
# Predicted vector: [-0.2065625   0.62379571  0.75379762],
# Actual vector: [-0.21393708  0.62148414  0.75026499]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 11.13065 mm
#
# Target: [-175.52633532 1287.83358648 1375.01907534]
# Predicted vector: [-0.09599758  0.70433253  0.70334924],
# Actual vector: [-0.10212709  0.70048537  0.70270866]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 11.82829 mm
#
# Target: [-472.00534211  815.81707697  854.47513813]
# Predicted vector: [-0.39272611  0.67879034  0.62049165],
# Actual vector: [-0.39878985  0.67792328  0.61342957]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 11.92339 mm
#
# Target: [ 98.68530777 956.54684168 509.19447192]
# Predicted vector: [0.09578147 0.92840022 0.359025  ],
# Actual vector: [0.09359354 0.92382442 0.36427715]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 6.92909 mm
#
# Target: [-237.14221393 1290.14155104 1438.63229168]
# Predicted vector: [-0.12578004  0.68429004  0.71828025],
# Actual vector: [-0.13221038  0.68082409  0.71687386]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 12.63908 mm
#
# Target: [-166.31957808 1432.06221853  696.67282952]
# Predicted vector: [-0.10759967  0.92646598  0.36067034],
# Actual vector: [-0.10953915  0.92308418  0.36169865]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 4.73734 mm
#
# Target: [  64.7603173  1269.50810982  855.8375388 ]
# Predicted vector: [0.044198   0.86642123 0.49735378],
# Actual vector: [0.04063229 0.86159572 0.50091016]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 9.21321 mm
#
# Target: [-343.17707752 1076.74507466  902.44302164]
# Predicted vector: [-0.24939304  0.78249027  0.57053667],
# Actual vector: [-0.25405297  0.78008589  0.56730261]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 8.15734 mm
#
# Target: [-147.53651448  757.37452407  895.78256337]
# Predicted vector: [-0.13155941  0.6753565   0.72566227],
# Actual vector: [-0.13811956  0.67197672  0.72407143]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 7.45844 mm
#
# Target: [-342.04817559  518.53254745 1205.00217422]
# Predicted vector: [-0.24664936  0.37391143  0.89406618],
# Actual vector: [-0.25805183  0.37381309  0.8880215 ]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 16.83215 mm
#
# Target: [345.89528025 905.35598121 394.78680015]
# Predicted vector: [0.34560934 0.90460755 0.2494782 ],
# Actual vector: [0.34380067 0.89954828 0.25985217]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 11.60162 mm
#
# Target: [-92.2110429  865.75802475 867.60290679]
# Predicted vector: [-0.07944487  0.74589809  0.66130519],
# Actual vector: [-0.08497254  0.74185634  0.66131534]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 6.84037 mm
#
# Target: [ 156.40479644 1275.30501054 1257.59431347]
# Predicted vector: [0.09036566 0.7368302  0.67001142],
# Actual vector: [0.08480621 0.73086563 0.67346305]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 14.12822 mm
#
# Target: [-157.80841388  559.76188948 1209.9579095 ]
# Predicted vector: [-0.11295441  0.40066035  0.90923737],
# Actual vector: [-0.12281485  0.39809237  0.90628259]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 12.27938 mm
#
# Target: [236.14562844 583.8584165  563.13634966]
# Predicted vector: [0.30574454 0.7559383  0.57885884],
# Actual vector: [0.30069862 0.74837306 0.58687925]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 9.28949 mm
#
# Target: [-250.40323733 1209.13218486 1459.49327918]
# Predicted vector: [-0.13495707  0.65167263  0.7463976 ],
# Actual vector: [-0.14184741  0.64838609  0.74456963]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 13.18633 mm
#
# Target: [-456.70132967  607.50674376  656.95346919]
# Predicted vector: [-0.48951932  0.65116143  0.57996519],
# Actual vector: [-0.49542248  0.65101126  0.57065756]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 11.47659 mm
#
# Target: [363.93789006 822.25860291 558.13208335]
# Predicted vector: [0.36608396 0.82710731 0.42646925],
# Actual vector: [0.36244481 0.82042803 0.43639519]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 12.44076 mm
#
# Target: [ -99.25598971 1318.2484662   501.46432416]
# Predicted vector: [-0.07248709  0.96272275  0.26059647],
# Actual vector: [-0.07338763  0.95940848  0.26279038]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 4.23816 mm
#
# Target: [ 494.86854852 1089.4818974   639.94057267]
# Predicted vector: [0.38128802 0.83942776 0.38727313],
# Actual vector: [0.3779922  0.83300827 0.39765346]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 16.35887 mm
#
# Target: [-255.55647647  705.40316295 1020.92455254]
# Predicted vector: [-0.20902155  0.57695454  0.78957802],
# Actual vector: [-0.21708554  0.57489243  0.78567278]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 10.54254 mm
#
# Target: [-348.45288182 1468.7606581   755.85958996]
# Predicted vector: [-0.21362894  0.90046547  0.37884643],
# Actual vector: [-0.2157497   0.89771754  0.37744462]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 4.87379 mm
#
# Target: [-376.74070781 1215.95741074  914.11465365]
# Predicted vector: [-0.25140165  0.81141671  0.52763637],
# Actual vector: [-0.25546499  0.80897047  0.52460801]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 8.00425 mm
#
# Target: [ 218.15648479 1176.86988651  498.6852659 ]
# Predicted vector: [0.17473523 0.94262898 0.28446127],
# Actual vector: [0.17310748 0.93804779 0.29156353]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 10.26462 mm
#
# Target: [-270.30809552  975.76880046  538.83088711]
# Predicted vector: [-0.2482833   0.89626282  0.36751648],
# Actual vector: [-0.25027491  0.89374083  0.36537509]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 3.73613 mm
#
# Target: [-248.94498731  834.68813533  617.71716488]
# Predicted vector: [-0.24912079  0.83527761  0.49015319],
# Actual vector: [-0.25267344  0.83277885  0.48738555]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 4.99580 mm
#
# Target: [-403.93843146  852.63611217  329.77585566]
# Predicted vector: [-0.42034022  0.88725712  0.18997077],
# Actual vector: [-0.42013046  0.88564788  0.18446512]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 5.44578 mm
#
# Target: [-120.53055048  648.54384122  550.74010597]
# Predicted vector: [-0.15309422  0.82376055  0.5458761 ],
# Actual vector: [-0.15723655  0.82047596  0.54498167]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 3.69950 mm
#
# Target: [-473.73787352 1276.2401803  1147.92770811]
# Predicted vector: [-0.27688091  0.74591154  0.6057664 ],
# Actual vector: [-0.28214916  0.74384394  0.60166203]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 11.67870 mm
#
# Target: [256.807551   580.90271994 631.11832604]
# Predicted vector: [0.31144211 0.70448693 0.6377319 ],
# Actual vector: [0.30569611 0.69630936 0.64545512]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 10.33036 mm
#
# Target: [-401.71549968  989.33794386  711.30576527]
# Predicted vector: [-0.33031259  0.81348812  0.47867595],
# Actual vector: [-0.33386322  0.81161529  0.47405182]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 7.62404 mm
#
# Target: [ 468.81482063 1320.91442337 1042.89299636]
# Predicted vector: [0.27939614 0.7872157  0.5497538 ],
# Actual vector: [0.27476689 0.78013706 0.55749303]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 18.83059 mm
#
# Target: [ 347.47159259  985.44276437 1135.61798634]
# Predicted vector: [0.23478414 0.66585682 0.70817448],
# Actual vector: [0.22849058 0.65790008 0.71405091]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 16.71831 mm
#
# Target: [-62.25508533 757.34059908 690.51826075]
# Predicted vector: [-0.06516047  0.79268501  0.60613908],
# Actual vector: [-0.06996783  0.78854145  0.60680808]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 5.14573 mm
#
# Target: [298.43364001 966.35866106 714.70219622]
# Predicted vector: [0.25506937 0.82594071 0.50275397],
# Actual vector: [0.25102234 0.81942821 0.51032769]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 12.28748 mm
#
# Target: [-378.42724165 1446.61133912 1039.59582557]
# Predicted vector: [-0.21583969  0.82508898  0.52215074],
# Actual vector: [-0.2197634   0.82233816  0.51997419]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 8.37019 mm
#
# Target: [ 319.55920819  683.83457146 1214.44201704]
# Predicted vector: [0.22603585 0.48370105 0.84554189],
# Actual vector: [0.21794474 0.4742458  0.8500001 ]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 17.60408 mm
#
# Target: [-29.52434525 501.61838187 414.35703511]
# Predicted vector: [-0.05101571  0.86675659  0.49611532],
# Actual vector: [-0.05450825  0.86268562  0.49770627]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 2.59747 mm
#
# Target: [-163.27458468  567.3809622   922.40357276]
# Predicted vector: [-0.15230937  0.52927673  0.8346664 ],
# Actual vector: [-0.16084434  0.52667124  0.83165837]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 8.82127 mm
#
# Target: [-365.0277904   550.57711155  416.58051237]
# Predicted vector: [-0.50891439  0.76760352  0.38960361],
# Actual vector: [-0.51159378  0.76683878  0.38097144]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 7.39687 mm
#
# Target: [ 32.92035863 613.87709812 844.00949661]
# Predicted vector: [0.03294311 0.6143014  0.7883835 ],
# Actual vector: [0.02591391 0.60865177 0.78979785]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 7.63199 mm
#
# Target: [ 446.14977544 1470.52935293  793.84410895]
# Predicted vector: [0.26695342 0.87989024 0.39310183],
# Actual vector: [0.26400033 0.87409959 0.40145098]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 17.25720 mm
#
# Target: [116.34620834 761.24384349 315.50431139]
# Predicted vector: [0.14756768 0.96552339 0.21444896],
# Actual vector: [0.14668004 0.96146901 0.22129496]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 5.98213 mm
#
# Target: [ -37.24086062 1156.82857046  652.2584506 ]
# Predicted vector: [-0.02938251  0.91272139  0.40752465],
# Actual vector: [-0.03189807  0.90872741  0.41000752]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 5.71468 mm
#
# Target: [416.68641302 868.90387494 789.57051085]
# Predicted vector: [0.35459701 0.73943068 0.57227899],
# Actual vector: [0.34942149 0.73147516 0.5811694 ]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 15.25668 mm
#
# Target: [  67.48819193  945.85674091 1023.21633685]
# Predicted vector: [0.05071219 0.71073872 0.70162578],
# Actual vector: [0.04479101 0.70511526 0.70407058]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 10.10902 mm
#
# Target: [-265.45633002 1048.46919384  774.61409158]
# Predicted vector: [-0.21040669  0.83104041  0.51487946],
# Actual vector: [-0.21422627  0.8282411   0.51286737]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 5.92871 mm
#
# Target: [ 126.64599614  622.04190055 1386.56081112]
# Predicted vector: [0.07938926 0.38993291 0.91741467],
# Actual vector: [0.07061981 0.38271273 0.91839695]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 15.23587 mm
#
# Target: [ 234.91262941 1462.41419288 1458.74060995]
# Predicted vector: [0.11672327 0.72664366 0.67702635],
# Actual vector: [0.11105577 0.72034174 0.68094313]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 17.57305 mm
#
# Target: [ 449.87311994 1379.52492374  367.86031602]
# Predicted vector: [0.30654834 0.94002298 0.14961591],
# Actual vector: [0.30579829 0.93589768 0.15966241]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 15.67663 mm
#
# Target: [-116.77252064  990.4325811  1003.15688019]
# Predicted vector: [-0.0866755   0.73515785  0.67233198],
# Actual vector: [-0.09236188  0.73119401  0.67211142]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 8.14203 mm
#
# Target: [ 251.28158569 1300.72584576  405.18919548]
# Predicted vector: [0.1861806  0.96373914 0.19116394],
# Actual vector: [0.18540943 0.95968568 0.19883635]
# Predicted shortest dist: 0.00002 mm,
# Actual shortest dist: 11.28529 mm
#
# Target: [ 369.92222919 1296.9719378  1486.91465301]
# Predicted vector: [0.19005429 0.66634296 0.72101763],
# Actual vector: [0.18373642 0.65885225 0.72599159]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 20.40588 mm
#
# Target: [-439.61231426  700.87393741 1463.25418176]
# Predicted vector: [-0.26076153  0.41573212  0.87130375],
# Actual vector: [-0.27151737  0.41543532  0.86521729]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 20.02516 mm
#
# Target: [-378.01233116 1045.34332597 1438.31121052]
# Predicted vector: [-0.21359296  0.5906632   0.77813562],
# Actual vector: [-0.22146582  0.58858863  0.77422572]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 15.12085 mm
#
# Target: [-317.22743495  653.69430383  490.53763356]
# Predicted vector: [-0.39169209  0.80713981  0.44170423],
# Actual vector: [-0.3948529   0.80566439  0.43578117]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 6.18477 mm
#
# Target: [ 231.01533205 1295.80429313 1351.36821723]
# Predicted vector: [0.12683597 0.7114445  0.69120139],
# Actual vector: [0.12098979 0.70494619 0.69521327]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 16.37428 mm
#
# Target: [ 283.88953993 1331.13916589  949.54756206]
# Predicted vector: [0.17837181 0.83637354 0.51832692],
# Actual vector: [0.17436214 0.83036997 0.52439748]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 14.32796 mm
#
# Target: [-55.21544439 963.65587514 455.93695472]
# Predicted vector: [-0.05440374  0.94948946  0.30904691],
# Actual vector: [-0.05583723  0.94593926  0.31143261]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 3.63607 mm
#
# Target: [ 416.59434454 1235.63330234 1445.32714999]
# Predicted vector: [0.22091654 0.65524613 0.72239074],
# Actual vector: [0.21449526 0.64733901 0.72791012]
# Predicted shortest dist: 0.00002 mm,
# Actual shortest dist: 21.01687 mm
#
# Target: [ -88.81809713 1118.70599771  721.25556742]
# Predicted vector: [-0.07003324  0.88210182  0.4658237 ],
# Actual vector: [-0.07317437  0.87824316  0.4671655 ]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 5.44049 mm
#
# Target: [-300.71666934 1422.04233444  844.08600922]
# Predicted vector: [-0.18584505  0.87883235  0.43944889],
# Actual vector: [-0.18868944  0.87585572  0.43838592]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 5.71830 mm
#
# Target: [ 384.5411542   529.56230983 1127.52681015]
# Predicted vector: [0.29525373 0.40660211 0.8645808 ],
# Actual vector: [0.28629418 0.39529406 0.86987781]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 19.28894 mm
#
# Target: [ 436.30060259  719.17778274 1398.6489952 ]
# Predicted vector: [0.26881317 0.44309923 0.85522076],
# Actual vector: [0.26028062 0.43259052 0.86024915]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 22.51437 mm
#
# Target: [-334.56512    1321.07919418  866.63249007]
# Predicted vector: [-0.21593359  0.85264529  0.4757822 ],
# Actual vector: [-0.21925469  0.84988174  0.47385394]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 6.52098 mm
#
# Target: [-443.42902032  697.8410603  1204.51689821]
# Predicted vector: [-0.31067128  0.48891517  0.81513515],
# Actual vector: [-0.32034375  0.48858071  0.80844167]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 16.77299 mm
#
# Target: [ 396.60575748 1004.86778192  945.85581031]
# Predicted vector: [0.29040892 0.73580013 0.61176861],
# Actual vector: [0.28504903 0.72808769 0.61930971]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 16.14945 mm
#
# Target: [129.91829842 707.47260474 609.34569788]
# Predicted vector: [0.14918037 0.81236458 0.56374552],
# Actual vector: [0.14474099 0.80634565 0.56900429]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 7.40824 mm
#
# Target: [-389.63710248  820.17276025  895.77998987]
# Predicted vector: [-0.32282115  0.67952746  0.65880872],
# Actual vector: [-0.32917496  0.67812579  0.65322156]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 10.64126 mm
#
# Target: [-208.46795678  724.37450694 1085.29122645]
# Predicted vector: [-0.16219431  0.56358504  0.80997834],
# Actual vector: [-0.17031854  0.56096417  0.806982  ]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 10.46414 mm
#
# Target: [145.570669   662.66878237 435.54478219]
# Predicted vector: [0.19628258 0.89352024 0.40384988],
# Actual vector: [0.19341858 0.88809212 0.41084157]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 6.60792 mm
#
# Target: [136.12686648 955.76208351 380.35312466]
# Predicted vector: [0.13701302 0.96198384 0.236251  ],
# Actual vector: [0.13594407 0.95784708 0.24281133]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 7.33788 mm
#
# Target: [-175.10818142 1013.97852547  698.86037357]
# Predicted vector: [-0.1488395   0.86186755  0.48480009],
# Actual vector: [-0.15221681  0.85858112  0.48433217]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 4.69615 mm
#
# Target: [-347.30956452 1329.23922153 1252.21612643]
# Predicted vector: [-0.19401134  0.74252917  0.64110064],
# Actual vector: [-0.19953041  0.73970341  0.63869839]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 11.00837 mm
#
# Target: [ 56.22102095 639.10174878 990.01452715]
# Predicted vector: [0.04869223 0.55351694 0.83141329],
# Actual vector: [0.04110593 0.54747901 0.83275818]
# Predicted shortest dist: 0.00000 mm,
# Actual shortest dist: 9.51570 mm
#
# Target: [  75.22266263 1236.00188017  976.39989292]
# Predicted vector: [0.04991426 0.8201533  0.56996239],
# Actual vector: [0.04553605 0.81500761 0.57323487]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 10.23939 mm
#
# Target: [-30.02749473 830.44482479 323.86028858]
# Predicted vector: [-0.03533986  0.97736453  0.2085897 ],
# Actual vector: [-0.03576903  0.97405677  0.21176198]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 3.15903 mm
#
# Target: [-499.19842025 1179.79863528 1234.44862582]
# Predicted vector: [-0.29168531  0.68936503  0.66309542],
# Actual vector: [-0.29794634  0.68764709  0.65823902]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 13.72987 mm
#
# Target: [-322.76098037 1453.98449452  671.1534175 ]
# Predicted vector: [-0.20415037  0.91966346  0.33547241],
# Actual vector: [-0.20575896  0.91689547  0.33447734]
# Predicted shortest dist: 0.00001 mm,
# Actual shortest dist: 3.81921 mm
#
# 22.51437163729869

# %% [markdown]
# As one can see, the error is quite significant: for a noise magnitude of 0.5 (unrealistically low) we get an error of ~40mm which is almost the diameter of our ball. What's especially interesting is if you compare the predict and actual vectors the difference betwene them is tiny! It is <=1mm for most vectors, and yet it results in a huge error near the target.
#
# This indicates that our mechanical assembly is highly sensitive to noise: even a tiny offset somewhere would make the aim bad. Therefore after performing this initial optimization we need to put a laser pointer in the barrel and do a second round of optimization based on real life measurements.
#
# One way of doing this could be to aim the gun at the target with the predicted angles. We will see the laser dot slightly off-target. We can then manually adjust the motor angles to point the laser at the target. These manually adjusted angles can be used to recalculate the directions and positions of the motor axes and gun axis.
#
# Or maybe we can do this manual step first, get the accurate values for actual axes and then only use the `scipy.optimize` during the actual game.

# %% [markdown]
# # Ideal (Intersecting) Axes Test

# %% [markdown]
# The next little bit serves to compare the speed and error of an ideal axes setup to the above.
